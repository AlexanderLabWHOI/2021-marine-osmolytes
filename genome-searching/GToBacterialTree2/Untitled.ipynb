# %%
import pandas as pd

# %%
order = []
with open('tree-order', 'r') as f:
    for line in f:
        order.append(line.strip())
data  = pd.read_csv('../predict_synthesis/predicted-bacterial-osmolyte-synthesis.tsv', sep = '\t', header=[0,1], index_col=0)

# %%
SYNTH = data.xs('SYNTHESIS', level=1, drop_level=False, axis=1)
SYNTH.columns = SYNTH.columns.droplevel(1)
SYNTH = SYNTH.loc[order]
SYNTH.to_csv('TREE_SYNTH.tsv', sep = '\t')

# %%
BD = data.xs('BREAKDOWN', level=1, drop_level=False, axis=1)
BD.columns = BD.columns.droplevel(1)
BD = BD.loc[order]
BD.to_csv('TREE_BD.tsv', sep = '\t')

# %%
TRAN = data.xs('TRANSPORT', level=1, drop_level=False, axis=1)
TRAN.columns = TRAN.columns.droplevel(1)
TRAN = TRAN.loc[order]
TRAN.to_csv('TREE_TRAN.tsv', sep = '\t')

# %%
SYNTH.loc[order]
# Out:
#                  DMSP  Ectoine  GABA  Glutamate  Glutamine  Glycerol  \
# GCF_002214395.1     0        0     0          1          1         1
# GCF_003312585.1     0        0     1          1          1         1
# GCF_001991055.1     0        0     1          1          1         1
# GCF_002140055.1     0        0     1          1          1         1
# GCF_002906455.1     0        0     1          1          1         1
# ...               ...      ...   ...        ...        ...       ...
# GCF_002831645.1     0        0     0          1          1         0
# GCF_003410315.1     0        0     0          1          1         0
# GCF_000211855.2     0        0     0          1          1         0
# GCF_002831665.1     0        0     0          1          1         0
# GCF_001971745.1     0        0     0          1          1         0
#
#                  Glycine betaine  Hydroxyectoine  Mannitol  Proline  \
# GCF_002214395.1                1               0         0        1
# ...

# %%
colors = ["#ffafbb",
"#ffa38e",
"#b56548",
"#e17b50",
"#f0cdbf",
"#ffba90",
"#ffb767",
"#967448",
"#ca933b",
"#ffde7e",
"#867b32",
"#b3aa42",
"#7b7e41",
"#dae87d",
"#747f53",
"#f6ffd9",
"#648433",
"#c8ffa5",
"#9bda7c",
"#389449",
"#c0ffd2",
"#42c689",
"#02ab93",
"#78ffe5",
"#00dcc2",
"#58827d",
"#018b82",
"#b9fbff",
"#00d6ea",
"#00abf0",
"#4287e4",
"#e3d8ff",
"#ddc6ff",
"#8b6daf",
"#c371c4",
"#ffb8e8",
"#c45292",
"#f87cb5",
"#b4607f"]

# %%
order = pd.read_csv('order', header=None, )

# %%
cdict = {}
for z,color in zip(order[0].unique(), colors):
    cdict[z]=color

# %%
order[1] = order[0].map(cdict)

# %%
order.to_csv('Order_colored')
